# %%
import pandas as pd
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
from googletrans import Translator

# %% [markdown]
# #### Import

# %%
df = pd.read_csv(r'C:\Users\John\Desktop\Patent Datasets\data_clean.csv.gz', compression='gzip')

# %% [markdown]
# #### Clean length of claims

# %%
# Check if each value in 'column1' is in 'column2'
df['in_our_db'] = df['citation_lens_id'].isin(df['lens_id'])

# %%
df_claim_clean = df[df['claim'].str.len() >= 50]

# %% [markdown]
# #### Drop NaN

# %%
df_cleaned = df_claim_clean.dropna()

# %%
true_count = df_cleaned['in_our_db'].sum()
print("Number of True values:", true_count)
# Out:
# Number of True values: 40522

# %%
#Indication for citations that are in our database
df_cleaned_2 = df_cleaned[df_cleaned['in_our_db'] == True]

# %%
df_cleaned_2
# Out:
#                     lens_id  \
# 5       000-374-150-323-590
# 14      000-602-602-272-491
# 186     001-272-910-808-558
# 192     001-540-413-298-698
# 194     001-540-413-298-698
# ...                     ...
# 545507  180-811-430-280-652
# 545508  180-811-430-280-652
# 545511  197-847-474-005-427
# 545518  001-817-748-239-023
# 545519  001-817-748-239-023
#
#                                                     claim  \
# 5       A wind turbine (1) having a rotor (4) with at ...
# 14      Method of updating software and/or firmware of...
# 186     A computer-based method for providing a soft s...
# 192                                       Patentansprüche
# 194                                       Patentansprüche
# ...                                                   ...
# 545507  1 . A connecting joint for attaching a wind tu...
# 545508  1 . A connecting joint for attaching a wind tu...
# 545511  1. Method for assembling an offshore support s...
# 545518  1. A pitch controlled wind turbine comprising ...
# 545519  1. A pitch controlled wind turbine comprising ...
#
#                                                     title  \
# 5          Wind turbine with hydraulic blade pitch system
# 14      UPDATING SOFTWARE AND/OR FIRMWARE OF A PLURALI...
# 186     A COMPUTER-BASED METHOD AND A PREDICTION DEVIC...
# 192                                          WIND TURBINE
# 194                                          WIND TURBINE
# ...                                                   ...
# 545507  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...
# 545508  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...
# 545511  METHOD FOR ASSEMBLING AN OFFSHORE SUPPORT STRU...
# 545518                    A PITCH CONTROLLED WIND TURBINE
# 545519                    A PITCH CONTROLLED WIND TURBINE
#
#                                               description citation_doc_number  \
# 5       The present invention relates to a wind turbin...        US2007217912
# 14      Field of invention The present invention relat...        US2011145811
# 186     The control of wind turbines can be considered...        US2014100703
# 192     Windturbine Technisches Gebiet Die Erfindung b...           EP1035325
# 194     Windturbine Technisches Gebiet Die Erfindung b...        US2009079161
# ...                                                   ...                 ...
# 545507  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...           EP2551512
# 545508  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...           EP2138716
# 545511  Method for assembling an offshore support stru...        WO2011147472
# 545518  A Pitch Controlled Wind Turbine FIELD OF THE I...        WO2022128040
# 545519  A Pitch Controlled Wind Turbine FIELD OF THE I...        US2012051914
#
#            citation_lens_id citation_phase citation_category  in_our_db
# 5       120-349-166-665-84X            SEA              Y, D       True
# 14      095-788-761-259-678            SEA                 Y       True
# 186     157-662-824-962-162            SEA                 X       True
# 192     159-571-171-881-339            ISR           X, Y, I       True
# 194     190-908-495-224-524            ISR                 Y       True
# ...                     ...            ...               ...        ...
# 545507  017-859-941-253-624            ISR                 A       True
# 545508  120-106-328-683-092            ISR                 A       True
# 545511  187-844-090-869-529            ISR              D, A       True
# 545518  070-871-524-178-129            ISR           X, A, I       True
# 545519  058-855-336-419-859            ISR           X, A, I       True
#
# [40522 rows x 9 columns]

# %%
unique_count = df_cleaned_2['lens_id'].nunique()

print("Number of unique values:", unique_count)

unique_values = df_cleaned_2['citation_category'].unique()
print("Unique values:", unique_values)
# Out:
# Number of unique values: 14717
# Unique values: ['Y, D' 'Y' 'X' 'X, Y, I' 'A' 'I, Y' 'X, I' 'X, A' 'Y, A' 'X, D' 'I'
#  'Y, D, A' 'X, D, A' 'A, D' 'A, P' 'X, P' 'X, A, I' 'X, Y' 'I, A, Y' 'E'
#  'X, A, Y' 'X, A, Y, I' 'X, D, A, I' 'I, A' 'X, Y, A' 'X, D, I' 'D, I, Y'
#  'I, D' 'I, D, Y' 'P, A' 'Y, A, X' 'X, D, Y, I' 'A, Y' 'P, X' 'D, X'
#  'D, A' 'Y, X' 'D, Y' 'Y, P' 'I, P' 'X, D, Y' 'L' 'D, X, I' 'A, X'
#  'X, D, A, Y, I' 'D, P' 'Y, D, A, D' 'A, E' 'E, X' 'D, X, A' 'X, P, A'
#  'X, I, A' 'X, P, I' 'D, X, Y' 'I, D, A' 'X, D, A, Y' 'D, A, A' 'X, D, P'
#  'P, X, Y' 'P, D, X' 'D, Y, A' 'T' 'D' 'P, D, A' 'I, D, A, Y' 'A, L'
#  'P, Y' 'X, D, Y, A' 'X, E' 'I, X, Y' 'P' 'X, I, Y' 'X, P, A, I' 'P, A, D'
#  'Y, P, A' 'D, X, Y, A' 'P, X, L' 'A, X, Y' 'D, X, D, Y, D' 'D, A, Y'
#  'Y, D, A, Y' 'X, D, P, A' 'X, D, A, D' 'E, A' 'D, X, A, I' 'D, Y, D, A'
#  'E, D' 'A, P, L']

# %%
# Assuming df and df_cleaned_2 are already loaded

# Step 1: Filter df based on citation_lens_id in df_cleaned_2
filtered_df = df[df['lens_id'].isin(df_cleaned_2['citation_lens_id'])]

# Step 2: Drop duplicates in the filtered dataframe based on 'lens_id'
filtered_df = filtered_df.drop_duplicates(subset='lens_id')

# Step 3: Merge df_cleaned_2 with filtered_df to get the required columns
merged_df = df_cleaned_2.merge(
    filtered_df[['lens_id', 'title', 'description', 'claim']],
    how='left',
    left_on='citation_lens_id',
    right_on='lens_id'
)

# # Step 4: Drop 'lens_id' column after merge if not needed
# merged_df = merged_df.drop(columns=['lens_id'])

# %%
df_filtered_merged_final = merged_df[merged_df["claim_x"].apply(lambda x: len(x) >= 30)]

# %% [markdown]
# #### Translation

# %%
df_filtered_merged_translate = df_filtered_merged_final.copy()

# %%
# Fix random seed for consistent results
DetectorFactory.seed = 0

# Define a function to detect language and handle exceptions
def is_not_english(text):
    try:
        return detect(text) != 'en'
    except LangDetectException:
        return False  # Consider empty or non-detectable text as English

# Apply function to detect non-English rows
non_english_count = df_filtered_merged_translate["description_y"].apply(is_not_english).sum()
print("Number of non-English rows:", non_english_count)
# Out:
# Number of non-English rows: 2212

# %%
# Initialize the translator
translator = Translator()

# Function to detect language and translate if not English
def translate_to_english(text):
    try:
        # Detect language
        lang = detect(text)
        # Translate only if language is not English
        if lang != 'en':
            translated = translator.translate(text, src=lang, dest='en')
            return translated.text
    except:
        pass
    return text

# %%
df_filtered_merged_translate['claim_x_trans'] = df_filtered_merged_translate['claim_x'].apply(translate_to_english)

# %%
# Fix random seed for consistent results
DetectorFactory.seed = 0

# Define a function to detect language and handle exceptions
def is_not_english(text):
    try:
        return detect(text) != 'en'
    except LangDetectException:
        return False  # Consider empty or non-detectable text as English

# Apply function to detect non-English rows
non_english_count = df_filtered_merged_translate["claim_x_trans"].apply(is_not_english).sum()
print("Number of non-English rows in claims:", non_english_count)
# Out:
# Number of non-English rows in claims: 0

# %%
df_filtered_merged_translate['description_y_trans'] = df_filtered_merged_translate['description_y'].apply(translate_to_english)

# %%
# Fix random seed for consistent results
DetectorFactory.seed = 0

# Define a function to detect language and handle exceptions
def is_not_english(text):
    try:
        return detect(text) != 'en'
    except LangDetectException:
        return False  # Consider empty or non-detectable text as English

# Apply function to detect non-English rows
non_english_count = df_filtered_merged_translate["description_y_trans"].apply(is_not_english).sum()
print("Number of non-English rows in description_y:", non_english_count)

# %%
num_nan = df_filtered_merged_translate['claim_x_trans'].isna().sum()


print(f"Number of NaN values in column 'column_name': {num_nan}")
# Out:
# Number of NaN values in column 'column_name': 0

# %%
# Check where the cells differ between 'description_y' and 'description_y_trans'
diff_rows = df_filtered_merged_translate[df_filtered_merged_translate['description_y'] != df_filtered_merged_translate['description_y_trans']]

# # Print the first 5 rows where there are differences
# print("First 5 rows where 'description_y' differs from 'description_y_trans':")
# print(diff_rows.head(5))

# %%
df_filtered_merged_translate
# Out:
#                  lens_id_x                                            claim_x  \
# 0      000-374-150-323-590  A wind turbine (1) having a rotor (4) with at ...
# 1      000-602-602-272-491  Method of updating software and/or firmware of...
# 2      001-272-910-808-558  A computer-based method for providing a soft s...
# 8      002-215-058-157-360  1. A modular drive system (I,I',I' 1 ) for a t...
# 11     002-847-069-458-789  A system for the erection of a tower (T) compr...
# ...                    ...                                                ...
# 40517  180-811-430-280-652  1 . A connecting joint for attaching a wind tu...
# 40518  180-811-430-280-652  1 . A connecting joint for attaching a wind tu...
# 40519  197-847-474-005-427  1. Method for assembling an offshore support s...
# 40520  001-817-748-239-023  1. A pitch controlled wind turbine comprising ...
# 40521  001-817-748-239-023  1. A pitch controlled wind turbine comprising ...
#
#                                                  title_x  \
# 0         Wind turbine with hydraulic blade pitch system
# 1      UPDATING SOFTWARE AND/OR FIRMWARE OF A PLURALI...
# 2      A COMPUTER-BASED METHOD AND A PREDICTION DEVIC...
# 8      A MODULAR DRIVE SYSTEM, A LOAD UNIT AND A TEST...
# 11     A SYSTEM FOR THE ERECTION OF A WIND TURBINE TO...
# ...                                                  ...
# 40517  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...
# 40518  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...
# 40519  METHOD FOR ASSEMBLING AN OFFSHORE SUPPORT STRU...
# 40520                    A PITCH CONTROLLED WIND TURBINE
# 40521                    A PITCH CONTROLLED WIND TURBINE
#
#                                            description_x citation_doc_number  \
# 0      The present invention relates to a wind turbin...        US2007217912
# 1      Field of invention The present invention relat...        US2011145811
# 2      The control of wind turbines can be considered...        US2014100703
# 8      A modular drive system, a load unit and a test...           EP2708738
# 11     Background of the invention Due to the increas...        WO2018185111
# ...                                                  ...                 ...
# 40517  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...           EP2551512
# 40518  JOINT FOR CONNECTING A WIND TURBINE ROTOR BLAD...           EP2138716
# 40519  Method for assembling an offshore support stru...        WO2011147472
# 40520  A Pitch Controlled Wind Turbine FIELD OF THE I...        WO2022128040
# 40521  A Pitch Controlled Wind Turbine FIELD OF THE I...        US2012051914
#
#           citation_lens_id citation_phase citation_category  in_our_db  \
# 0      120-349-166-665-84X            SEA              Y, D       True
# 1      095-788-761-259-678            SEA                 Y       True
# 2      157-662-824-962-162            SEA                 X       True
# 8      066-843-097-284-249            ISR                 A       True
# 11     180-717-094-409-013            SEA                 A       True
# ...                    ...            ...               ...        ...
# 40517  017-859-941-253-624            ISR                 A       True
# 40518  120-106-328-683-092            ISR                 A       True
# 40519  187-844-090-869-529            ISR              D, A       True
# 40520  070-871-524-178-129            ISR           X, A, I       True
# 40521  058-855-336-419-859            ISR           X, A, I       True
#
#                  lens_id_y                                            title_y  \
# 0      120-349-166-665-84X            CONTROL UNIT FOR ROTOR BLADE ADJUSTMENT
# 1      095-788-761-259-678  METHOD AND SYSTEM FOR SOFTWARE UPDATE OF WIND ...
# 2      157-662-824-962-162  METHOD FOR THE COMPUTER-SUPPORTED GENERATION O...
# 8      066-843-097-284-249                                       Wind turbine
# 11     180-717-094-409-013      HOISTING SYSTEM FOR INSTALLING A WIND TURBINE
# ...                    ...                                                ...
# 40517  017-859-941-253-624              Wind turbine blade connector assembly
# 40518  120-106-328-683-092                                       Blade insert
# 40519  187-844-090-869-529  A SEGMENTED JACKET CONSTRUCTION, IN PARTICULAR...
# 40520  070-871-524-178-129  A PITCH CONTROLLED WIND TURBINE WITH BLADE CON...
# 40521  058-855-336-419-859     CABLE-STAYED ROTOR FOR WIND AND WATER TURBINES
#
#                                            description_y  \
# 0      CROSS-REFERENCE TO A RELATED APPLICATION The i...
# 1      BACKGROUND OF THE INVENTION The present disclo...
# 2      Method for the computer-aided generation of a ...
# 8      The present invention relates to a wind turbin...
# 11     Hoisting System for Installing a Wind Turbine ...
# ...                                                  ...
# 40517  FIELD OF THE INVENTION The present invention r...
# 40518  Object of the invention The invention describe...
# 40519  Description A segmented jacket construction, i...
# 40520  A PITCH CONTROLLED WIND TURBINE WITH BLADE CON...
# 40521  BACKGROUND OF THE INVENTION 1. Field of the In...
#
#                                                  claim_y  \
# 0      1 . An electrohydraulic control unit for rotor...
# 1      1 . A method for installing software data at a...
# 2      1 . A method for computer-aided generation of ...
# 8      A wind turbine having a yaw system that compri...
# 11                                           C L A I M S
# ...                                                  ...
# 40517  A wind turbine blade connector assembly (100) ...
# 40518  Blade insert coupled in the solid lamination l...
# 40519  1. A segmented jacket construction (1, 6, 10, ...
# 40520                                                 24
# 40521                                1 - 12 . (canceled)
#
#                                            claim_x_trans  \
# 0      A wind turbine (1) having a rotor (4) with at ...
# 1      Method of updating software and/or firmware of...
# 2      A computer-based method for providing a soft s...
# 8      1. A modular drive system (I,I',I' 1 ) for a t...
# 11     A system for the erection of a tower (T) compr...
# ...                                                  ...
# 40517  1 . A connecting joint for attaching a wind tu...
# 40518  1 . A connecting joint for attaching a wind tu...
# 40519  1. Method for assembling an offshore support s...
# 40520  1. A pitch controlled wind turbine comprising ...
# 40521  1. A pitch controlled wind turbine comprising ...
#
#                                      description_y_trans
# 0      CROSS-REFERENCE TO A RELATED APPLICATION The i...
# 1      BACKGROUND OF THE INVENTION The present disclo...
# 2      Method for the computer-aided generation of a ...
# 8      The present invention relates to a wind turbin...
# 11     Hoisting System for Installing a Wind Turbine ...
# ...                                                  ...
# 40517  FIELD OF THE INVENTION The present invention r...
# 40518  Object of the invention The invention describe...
# 40519  Description A segmented jacket construction, i...
# 40520  A PITCH CONTROLLED WIND TURBINE WITH BLADE CON...
# 40521  BACKGROUND OF THE INVENTION 1. Field of the In...
#
# [28279 rows x 15 columns]

# %%
df_filtered_merged_translate.to_excel("final_similarity_data_trans.xlsx", index=False)

# %% [markdown]
# #### Cleaning Only

# %%
df_filtered_merged_final_simple = df_filtered_merged_final.copy()

# %%
# Fix random seed for consistent results
DetectorFactory.seed = 0

# Define a function to detect language and handle exceptions
def is_not_english(text):
    try:
        return detect(text) != 'en'
    except LangDetectException:
        return False  # Consider empty or non-detectable text as English

# Apply function to detect non-English rows
non_english_count = df_filtered_merged_final_simple["claim_x"].apply(is_not_english).sum()
print("Number of non-English rows:", non_english_count)

count_below_50 = (df_filtered_merged_final_simple['claim_x'].str.len() < 30).sum()
print("Below 50 in claims:", count_below_50)
# Out:
# Number of non-English rows: 3359
# Below 50 in claims: 0

# %%
# Function to detect if the text is in English
def is_english(text):
    try:
        return detect(text) == 'en'
    except LangDetectException:
        return False  # Consider non-detectable text as not English

# %%
# Apply function to detect non-English rows
non_english_count_2 = df_filtered_merged_final_simple["description_y"].apply(is_not_english).sum()
print("Number of non-English rows:", non_english_count_2)
# Out:
# Number of non-English rows: 1469

# %%
df_filtered_merged_final_simple_export = df_filtered_merged_final_simple[df_filtered_merged_final_simple["claim_x"].apply(lambda x: not is_not_english(x))]

# %%
df_filtered_merged_final_simple_export = df_filtered_merged_final_simple[df_filtered_merged_final_simple["description_y"].apply(lambda x: not is_not_english(x))]

# %%
df_filtered_merged_final_simple_export.to_excel("final_similarity_data.xlsx", index=False)
